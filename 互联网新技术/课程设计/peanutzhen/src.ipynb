# %%
# 所有库的import请在此cell进行！
import pandas
import pickle
import numpy
import os
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.charts import Radar
from pyecharts.charts import Pie
from pyecharts.charts import Line
from pyecharts.commons.utils import JsCode
from scipy.stats import pearsonr
from scipy.stats import chi2_contingency

print('Loading dataset...')
# Out:
# Loading dataset...

# %%
# 清洗数据
if os.path.exists('./cooked.csv'):
    data = pandas.read_csv('./cooked.csv')
    data = data.drop('Unnamed: 0', axis=1)
    with open('./COLS_NAME.dat', 'rb') as f:
        COLS_NAME = pickle.load(f)
    data.columns = [idx for idx in range(len(COLS_NAME))]
    print('Data loading from cooked.csv.')
else:
    dataset = pandas.read_csv('dataset.csv')
    print(f'Total data: {dataset.shape[0]}')
    # 洗掉不必要的列
    data = dataset.drop(
        [
            'Unnamed: 0',
            '提交答卷时间',
            '所用时间',
            '来源',
            '来源详情',
            '来自IP',
            '1、请问您的学校所在地区和类别：'
        ],
        axis=1
    )

    # 列名含义，接下来使用下标访问
    # 下标为整型int64 不是str!
    COLS_NAME = data.columns.values.tolist()
    data.columns = [idx for idx in range(len(COLS_NAME))]

    # 地区有两个-3的异常值 清洗
    data = data[data[91] != -3]

    # 14题数据为1or2 因此全体-1 统一处理
    data.iloc[:,53:58] = data.iloc[:,53:58] - 1

    # 线上学习时间有错误值及空值 0~15
    data = data[data[22].isin([x for x in range(16)])].astype(int)
    print(f'Data cleaning completed')

NUMS = data.shape[0] # 样本总数 用于单选题！不可用于多选题统计数据！！
print(f'Total: {NUMS}.')
# Out:
# Data loading from cooked.csv.
# Total: 750841.

# %%
# 导出数据csv
if not os.path.exists('./cooked.csv'):
    data.to_csv('./cooked.csv')
    with open('./COLS_NAME.dat', 'wb') as f:
        pickle.dump(COLS_NAME, f)
    print('cooked.csv saved.')
print('cooked.csv has already existed.')
# Out:
# cooked.csv has already existed.

# %%
# 创建雷达图包装函数
def create_radar(schema, data, minv, maxv, title=''):
    radar = (
        Radar()
        .set_colors(["#4587E7"])
        .add_schema(
            schema=schema,
            shape="circle",
            center=["50%", "50%"],
            radius="80%",
            angleaxis_opts=opts.AngleAxisOpts(
                min_=0,
                max_=360,
                is_clockwise=False,
                interval=5,
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axislabel_opts=opts.LabelOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(is_show=False),
                splitline_opts=opts.SplitLineOpts(is_show=False),
            ),
            radiusaxis_opts=opts.RadiusAxisOpts(
                min_=minv,
                max_=maxv,
                interval=0.1,
                splitarea_opts=opts.SplitAreaOpts(
                    is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
                ),
            ),
            polar_opts=opts.PolarOpts(),
            splitarea_opt=opts.SplitAreaOpts(is_show=False),
            splitline_opt=opts.SplitLineOpts(is_show=False),
        )
        .add(
            series_name="",
            data=data,
            areastyle_opts=opts.AreaStyleOpts(opacity=0.1),
            linestyle_opts=opts.LineStyleOpts(width=1),
        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title=title),
            legend_opts=opts.LegendOpts()
        )
    )
    return radar

# 创建柱状图包装函数
def create_bar(keys, values, title='', label='', isRotated=False, isPercent=False):
    assert isinstance(values, list)
    ROTATE_OPT=None
    PERCENT_OPT=None
    if isRotated:
        ROTATE_OPT=opts.AxisOpts(
            axislabel_opts=opts.LabelOpts(rotate=30)
        )
    if isPercent:
        PERCENT_OPT=opts.LabelOpts(
            position="top",
            formatter=JsCode(
                "function(x){return Number(x.data*100).toFixed() + '%';}"
            ),
        )
    bar = (
        Bar()
        .add_xaxis(keys)
        .add_yaxis(label, values)
        .set_global_opts(
            xaxis_opts=ROTATE_OPT,
            title_opts=opts.TitleOpts(title=title),
            legend_opts=opts.LegendOpts(is_show=True)
        )
        .set_series_opts(
            label_opts=PERCENT_OPT
        )
    )
    return bar

# 创建饼状图包装函数
def create_pie(values, title=''):
    pie = (
        Pie()
        .add(
            "",
            values,
            radius=["40%", "55%"],
            label_opts=opts.LabelOpts(
                position="outside",
                formatter="{b|{b}: }{per|{d}%}  ",
                background_color="#eee",
                border_color="#aaa",
                border_width=1,
                border_radius=4,
                rich={
                    "a": {"color": "#999", "lineHeight": 22, "align": "center"},
                    "abg": {
                        "backgroundColor": "#e3e3e3",
                        "width": "100%",
                        "align": "right",
                        "height": 22,
                        "borderRadius": [4, 4, 0, 0],
                    },
                    "hr": {
                        "borderColor": "#aaa",
                        "width": "100%",
                        "borderWidth": 0.5,
                        "height": 0,
                    },
                    "b": {"fontSize": 16, "lineHeight": 33},
                    "per": {
                        "color": "#eee",
                        "backgroundColor": "#334455",
                        "padding": [2, 4],
                        "borderRadius": 2,
                    },
                },
            )
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title=title)
        )
    )
    return pie

# 创建折线图包装函数
def create_line(keys, values, title='', label='', isSmooth=False):
    line = (
        Line()
        .add_xaxis(keys)
        .add_yaxis(label, values, is_smooth=isSmooth)
        .set_series_opts(
            areastyle_opts=opts.AreaStyleOpts(opacity=0.5),
            label_opts=opts.LabelOpts(is_show=True),
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title=title),
            xaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
                is_scale=False,
                boundary_gap=False,
            ),
        )
    )
    return line

print('create_xxx func defined!')
# Out:
# create_xxx func defined!

# %%
# 分析参加调查的学生的年级分布（输出柱状图）
keys = ["一年级", "二年级", "三年级", "四年级", "五年级", "六年级", "初一", "初二", "初三", "高一", "高二", "高三"]
values = [0 for _ in range(12)]
for _, grade in data[1].items():
    values[grade-1] = values[grade-1] + 1

bar = create_bar(keys, values, "学生的年级分布", label="问卷人数")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ee704f82d80444d697a46a0c1dbf4e99" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ee704f82d80444d697a46a0c1dbf4e99 = echarts.init(
#                     document.getElementById('ee704f82d80444d697a46a0c1dbf4e99'), 'white', {renderer: 'canvas'});
#                 var option_ee704f82d80444d697a46a0c1dbf4e99 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u95ee\u5377\u4eba\u6570",
#             "legendHoverLink": true,
#             "data": [
#                 64152,
#                 64610,
#                 65743,
#                 71080,
#                 75424,
#                 75457,
#                 74840,
#                 70469,
#                 66845,
#                 46583,
#                 41541,
#                 34097
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u95ee\u5377\u4eba\u6570"
#             ],
#             "selected": {
#                 "\u95ee\u5377\u4eba\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e00\u5e74\u7ea7",
#                 "\u4e8c\u5e74\u7ea7",
#                 "\u4e09\u5e74\u7ea7",
#                 "\u56db\u5e74\u7ea7",
#                 "\u4e94\u5e74\u7ea7",
#                 "\u516d\u5e74\u7ea7",
#                 "\u521d\u4e00",
#                 "\u521d\u4e8c",
#                 "\u521d\u4e09",
#                 "\u9ad8\u4e00",
#                 "\u9ad8\u4e8c",
#                 "\u9ad8\u4e09"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5b66\u751f\u7684\u5e74\u7ea7\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ee704f82d80444d697a46a0c1dbf4e99.setOption(option_ee704f82d80444d697a46a0c1dbf4e99);
#         });
#     </script>

# %%
# 统计学生使用设备情况
keys = ['电视', '台式电脑', '平板', '手机', '音频', '纸质学习资料']
res = [data[idx].value_counts()[1] for idx in range(2,8)]
res = numpy.array(res)
res = res / res.sum()
res = [list(x) for x in zip(keys, res)]

pie = create_pie(res, "学生上课设备使用情况统计")
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0aeacc1869604098b13397f1656c946f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0aeacc1869604098b13397f1656c946f = echarts.init(
#                     document.getElementById('0aeacc1869604098b13397f1656c946f'), 'white', {renderer: 'canvas'});
#                 var option_0aeacc1869604098b13397f1656c946f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7535\u89c6",
#                     "value": 0.1031940523370096
#                 },
#                 {
#                     "name": "\u53f0\u5f0f\u7535\u8111",
#                     "value": 0.15628139477635275
#                 },
#                 {
#                     "name": "\u5e73\u677f",
#                     "value": 0.10111677618569223
#                 },
#                 {
#                     "name": "\u624b\u673a",
#                     "value": 0.4768952927148225
#                 },
#                 {
#                     "name": "\u97f3\u9891",
#                     "value": 0.026266824273526262
#                 },
#                 {
#                     "name": "\u7eb8\u8d28\u5b66\u4e60\u8d44\u6599",
#                     "value": 0.13624565971259664
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{b|{b}: }{per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u89c6",
#                 "\u53f0\u5f0f\u7535\u8111",
#                 "\u5e73\u677f",
#                 "\u624b\u673a",
#                 "\u97f3\u9891",
#                 "\u7eb8\u8d28\u5b66\u4e60\u8d44\u6599"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5b66\u751f\u4e0a\u8bfe\u8bbe\u5907\u4f7f\u7528\u60c5\u51b5\u7edf\u8ba1",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_0aeacc1869604098b13397f1656c946f.setOption(option_0aeacc1869604098b13397f1656c946f);
#         });
#     </script>

# %%
# 统计平台功能使用情况
keys = ['回看课程视频', '作业提交', '随堂测试', '视频会议', '作业批改反馈', '课堂发言', '班级通知', '班级圈', '优秀作业查看', '学科竞赛游戏', '屏幕共享', '弹幕', '讨论']
values = [int(data[idx].value_counts()[1]) for idx in range(8,20)]


bar = create_bar(keys, values, label='使用人数', title='平台功能使用情况', isRotated=True)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5d467d19ad9e49808f83a8dae1b1b668" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5d467d19ad9e49808f83a8dae1b1b668 = echarts.init(
#                     document.getElementById('5d467d19ad9e49808f83a8dae1b1b668'), 'white', {renderer: 'canvas'});
#                 var option_5d467d19ad9e49808f83a8dae1b1b668 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4f7f\u7528\u4eba\u6570",
#             "legendHoverLink": true,
#             "data": [
#                 523619,
#                 614682,
#                 205803,
#                 132917,
#                 369300,
#                 230616,
#                 458726,
#                 221314,
#                 314978,
#                 25556,
#                 71182,
#                 94203
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4f7f\u7528\u4eba\u6570"
#             ],
#             "selected": {
#                 "\u4f7f\u7528\u4eba\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u56de\u770b\u8bfe\u7a0b\u89c6\u9891",
#                 "\u4f5c\u4e1a\u63d0\u4ea4",
#                 "\u968f\u5802\u6d4b\u8bd5",
#                 "\u89c6\u9891\u4f1a\u8bae",
#                 "\u4f5c\u4e1a\u6279\u6539\u53cd\u9988",
#                 "\u8bfe\u5802\u53d1\u8a00",
#                 "\u73ed\u7ea7\u901a\u77e5",
#                 "\u73ed\u7ea7\u5708",
#                 "\u4f18\u79c0\u4f5c\u4e1a\u67e5\u770b",
#                 "\u5b66\u79d1\u7ade\u8d5b\u6e38\u620f",
#                 "\u5c4f\u5e55\u5171\u4eab",
#                 "\u5f39\u5e55",
#                 "\u8ba8\u8bba"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5e73\u53f0\u529f\u80fd\u4f7f\u7528\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5d467d19ad9e49808f83a8dae1b1b668.setOption(option_5d467d19ad9e49808f83a8dae1b1b668);
#         });
#     </script>

# %%
keys = ['20分钟', '20～30分钟', '30～45分钟', '45分钟以上']
res = [data[21].value_counts()[idx] for idx in range(1,5)]
res = numpy.array(res)
res = res / res.sum()
res = [list(x) for x in zip(keys, res)]

pie = create_pie(res, '学生上课时长情况统计')
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f9d5546c23ad4c378a6b63262e5c6a81" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f9d5546c23ad4c378a6b63262e5c6a81 = echarts.init(
#                     document.getElementById('f9d5546c23ad4c378a6b63262e5c6a81'), 'white', {renderer: 'canvas'});
#                 var option_f9d5546c23ad4c378a6b63262e5c6a81 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "20\u5206\u949f",
#                     "value": 0.14060633343144555
#                 },
#                 {
#                     "name": "20\uff5e30\u5206\u949f",
#                     "value": 0.2575751723733786
#                 },
#                 {
#                     "name": "30\uff5e45\u5206\u949f",
#                     "value": 0.32735159640989236
#                 },
#                 {
#                     "name": "45\u5206\u949f\u4ee5\u4e0a",
#                     "value": 0.27446689778528344
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{b|{b}: }{per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "20\u5206\u949f",
#                 "20\uff5e30\u5206\u949f",
#                 "30\uff5e45\u5206\u949f",
#                 "45\u5206\u949f\u4ee5\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5b66\u751f\u4e0a\u8bfe\u65f6\u957f\u60c5\u51b5\u7edf\u8ba1",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f9d5546c23ad4c378a6b63262e5c6a81.setOption(option_f9d5546c23ad4c378a6b63262e5c6a81);
#         });
#     </script>

# %%
# 每天在线学习时间分析
keys = [str(hour)+'小时' for hour in range(0,16)]
res = [int(data[22].value_counts()[idx]) for idx in range(0,16)]

bar = create_bar(
    keys=keys,
    values=res,
    title='学生每天在线学习时间统计',
    label='人数',
    isRotated=True
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d9c758900cd64617b2956cd4d6b2e982" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d9c758900cd64617b2956cd4d6b2e982 = echarts.init(
#                     document.getElementById('d9c758900cd64617b2956cd4d6b2e982'), 'white', {renderer: 'canvas'});
#                 var option_d9c758900cd64617b2956cd4d6b2e982 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4eba\u6570",
#             "legendHoverLink": true,
#             "data": [
#                 2673,
#                 37273,
#                 79150,
#                 127986,
#                 85620,
#                 72105,
#                 111348,
#                 49684,
#                 44553,
#                 47319,
#                 24974,
#                 8872,
#                 18545,
#                 5708,
#                 3099,
#                 31932
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4eba\u6570"
#             ],
#             "selected": {
#                 "\u4eba\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5c0f\u65f6",
#                 "1\u5c0f\u65f6",
#                 "2\u5c0f\u65f6",
#                 "3\u5c0f\u65f6",
#                 "4\u5c0f\u65f6",
#                 "5\u5c0f\u65f6",
#                 "6\u5c0f\u65f6",
#                 "7\u5c0f\u65f6",
#                 "8\u5c0f\u65f6",
#                 "9\u5c0f\u65f6",
#                 "10\u5c0f\u65f6",
#                 "11\u5c0f\u65f6",
#                 "12\u5c0f\u65f6",
#                 "13\u5c0f\u65f6",
#                 "14\u5c0f\u65f6",
#                 "15\u5c0f\u65f6"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5b66\u751f\u6bcf\u5929\u5728\u7ebf\u5b66\u4e60\u65f6\u95f4\u7edf\u8ba1",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d9c758900cd64617b2956cd4d6b2e982.setOption(option_d9c758900cd64617b2956cd4d6b2e982);
#         });
#     </script>

# %%
keys = ["能","监督下能","有时能,有时不能","基本不能","不适应"]
res = [data[23].value_counts()[idx] for idx in range(1,6)]
res = numpy.array(res)
res = res / res.sum()
res = [list(x) for x in zip(keys,res)]

pie = create_pie(res, '学生状态统计')
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4290b7d962fe475e9df8889f656ac0a4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4290b7d962fe475e9df8889f656ac0a4 = echarts.init(
#                     document.getElementById('4290b7d962fe475e9df8889f656ac0a4'), 'white', {renderer: 'canvas'});
#                 var option_4290b7d962fe475e9df8889f656ac0a4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u80fd",
#                     "value": 0.35683187252693976
#                 },
#                 {
#                     "name": "\u76d1\u7763\u4e0b\u80fd",
#                     "value": 0.13813044306317848
#                 },
#                 {
#                     "name": "\u6709\u65f6\u80fd,\u6709\u65f6\u4e0d\u80fd",
#                     "value": 0.4097565263484546
#                 },
#                 {
#                     "name": "\u57fa\u672c\u4e0d\u80fd",
#                     "value": 0.04120712640892013
#                 },
#                 {
#                     "name": "\u4e0d\u9002\u5e94",
#                     "value": 0.05407403165250699
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{b|{b}: }{per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u80fd",
#                 "\u76d1\u7763\u4e0b\u80fd",
#                 "\u6709\u65f6\u80fd,\u6709\u65f6\u4e0d\u80fd",
#                 "\u57fa\u672c\u4e0d\u80fd",
#                 "\u4e0d\u9002\u5e94"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5b66\u751f\u72b6\u6001\u7edf\u8ba1",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4290b7d962fe475e9df8889f656ac0a4.setOption(option_4290b7d962fe475e9df8889f656ac0a4);
#         });
#     </script>

# %%
keys = ["完全不需要","有时需要","完全需要"]
res = [data[24].value_counts()[idx] for idx in range(1,4)]
res = numpy.array(res)
res = res / res.sum()
res = [list(x) for x in zip(keys, res)]

pie = create_pie(res, '学习需要家人陪伴统计')
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="43276b25af7f46eaafcf96b489e6ab85" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_43276b25af7f46eaafcf96b489e6ab85 = echarts.init(
#                     document.getElementById('43276b25af7f46eaafcf96b489e6ab85'), 'white', {renderer: 'canvas'});
#                 var option_43276b25af7f46eaafcf96b489e6ab85 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b8c\u5168\u4e0d\u9700\u8981",
#                     "value": 0.5294769465173053
#                 },
#                 {
#                     "name": "\u6709\u65f6\u9700\u8981",
#                     "value": 0.39898194158283845
#                 },
#                 {
#                     "name": "\u5b8c\u5168\u9700\u8981",
#                     "value": 0.07154111189985629
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{b|{b}: }{per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5b8c\u5168\u4e0d\u9700\u8981",
#                 "\u6709\u65f6\u9700\u8981",
#                 "\u5b8c\u5168\u9700\u8981"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5b66\u4e60\u9700\u8981\u5bb6\u4eba\u966a\u4f34\u7edf\u8ba1",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_43276b25af7f46eaafcf96b489e6ab85.setOption(option_43276b25af7f46eaafcf96b489e6ab85);
#         });
#     </script>

# %%
keys = ["直播","录播","资源包","电视课堂","直播+录播","直播+资源包","录播+资源包","直播+录播+资源包","录播+资源包+线上辅导答疑"]
res = [int(data[idx].value_counts()[1]) for idx in range(25,34)]
res = numpy.array(res)
res = res / res.sum()

bar = create_bar(
    keys=keys,
    values=list(res),
    title='统计学生喜欢的课堂组织形式',
    isRotated=True,
    isPercent=True
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a2f7144cf83b4030ab68c3219d581a3e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a2f7144cf83b4030ab68c3219d581a3e = echarts.init(
#                     document.getElementById('a2f7144cf83b4030ab68c3219d581a3e'), 'white', {renderer: 'canvas'});
#                 var option_a2f7144cf83b4030ab68c3219d581a3e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 0.24914146926945613,
#                 0.1126603292872989,
#                 0.06496017536603736,
#                 0.10310666235284054,
#                 0.10411972539880915,
#                 0.06132279662003575,
#                 0.04330571155297098,
#                 0.0902944700908412,
#                 0.17108866006171
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data*100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u76f4\u64ad",
#                 "\u5f55\u64ad",
#                 "\u8d44\u6e90\u5305",
#                 "\u7535\u89c6\u8bfe\u5802",
#                 "\u76f4\u64ad+\u5f55\u64ad",
#                 "\u76f4\u64ad+\u8d44\u6e90\u5305",
#                 "\u5f55\u64ad+\u8d44\u6e90\u5305",
#                 "\u76f4\u64ad+\u5f55\u64ad+\u8d44\u6e90\u5305",
#                 "\u5f55\u64ad+\u8d44\u6e90\u5305+\u7ebf\u4e0a\u8f85\u5bfc\u7b54\u7591"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7edf\u8ba1\u5b66\u751f\u559c\u6b22\u7684\u8bfe\u5802\u7ec4\u7ec7\u5f62\u5f0f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a2f7144cf83b4030ab68c3219d581a3e.setOption(option_a2f7144cf83b4030ab68c3219d581a3e);
#         });
#     </script>

# %%
keys = ["学科课程新课","学科课程复习","音美体劳教育","专题教育"]
res = [data[idx].value_counts()[1] for idx in range(34,38)]
res = numpy.array(res)
res = res / res.sum()

bar = create_bar(
    keys=keys,
    values=list(res),
    title='统计学生对线上课程内容的喜爱情况',
    isRotated=True,
    isPercent=True
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="783bd4e722574fd2939ea2b8e87fb8f2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_783bd4e722574fd2939ea2b8e87fb8f2 = echarts.init(
#                     document.getElementById('783bd4e722574fd2939ea2b8e87fb8f2'), 'white', {renderer: 'canvas'});
#                 var option_783bd4e722574fd2939ea2b8e87fb8f2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 0.3604118075558199,
#                 0.286390145667511,
#                 0.16662322705107385,
#                 0.18657481972559528
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data*100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5b66\u79d1\u8bfe\u7a0b\u65b0\u8bfe",
#                 "\u5b66\u79d1\u8bfe\u7a0b\u590d\u4e60",
#                 "\u97f3\u7f8e\u4f53\u52b3\u6559\u80b2",
#                 "\u4e13\u9898\u6559\u80b2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7edf\u8ba1\u5b66\u751f\u5bf9\u7ebf\u4e0a\u8bfe\u7a0b\u5185\u5bb9\u7684\u559c\u7231\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_783bd4e722574fd2939ea2b8e87fb8f2.setOption(option_783bd4e722574fd2939ea2b8e87fb8f2);
#         });
#     </script>

# %%
keys = ["查阅线上资源","视频回放","教师线上答疑","社交软件咨询教师","同学交流","暂时放下"]
res = [data[idx].value_counts()[1] for idx in range(38,44)]
res = numpy.array(res)
res = res / res.sum()

bar = create_bar(
    keys,
    list(res),
    title='统计学生通过哪些方法解决未掌握知识点',
    isRotated=True,
    isPercent=True
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="acc79aa293714253add84fbb630fbdab" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_acc79aa293714253add84fbb630fbdab = echarts.init(
#                     document.getElementById('acc79aa293714253add84fbb630fbdab'), 'white', {renderer: 'canvas'});
#                 var option_acc79aa293714253add84fbb630fbdab = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 0.21318759690464495,
#                 0.3110329561736088,
#                 0.12356715138654123,
#                 0.15943723783670086,
#                 0.14864742819952118,
#                 0.044127629498982954
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data*100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u67e5\u9605\u7ebf\u4e0a\u8d44\u6e90",
#                 "\u89c6\u9891\u56de\u653e",
#                 "\u6559\u5e08\u7ebf\u4e0a\u7b54\u7591",
#                 "\u793e\u4ea4\u8f6f\u4ef6\u54a8\u8be2\u6559\u5e08",
#                 "\u540c\u5b66\u4ea4\u6d41",
#                 "\u6682\u65f6\u653e\u4e0b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7edf\u8ba1\u5b66\u751f\u901a\u8fc7\u54ea\u4e9b\u65b9\u6cd5\u89e3\u51b3\u672a\u638c\u63e1\u77e5\u8bc6\u70b9",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_acc79aa293714253add84fbb630fbdab.setOption(option_acc79aa293714253add84fbb630fbdab);
#         });
#     </script>

# %%
keys = ["不回答","偶尔参与回答","大多数情况下能回答","积极发言","没有问答环节"]
res = [data[idx].value_counts()[1] for idx in range(44,49)]
res = numpy.array(res)
res = res / res.sum()
res = [list(x) for x in zip(keys, res)]

pie = create_pie(res, '统计学生线上互动频率')
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1a3ca326d8d24e2399fa9cf78808cc8c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1a3ca326d8d24e2399fa9cf78808cc8c = echarts.init(
#                     document.getElementById('1a3ca326d8d24e2399fa9cf78808cc8c'), 'white', {renderer: 'canvas'});
#                 var option_1a3ca326d8d24e2399fa9cf78808cc8c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4e0d\u56de\u7b54",
#                     "value": 0.08916096426494924
#                 },
#                 {
#                     "name": "\u5076\u5c14\u53c2\u4e0e\u56de\u7b54",
#                     "value": 0.42397356769086275
#                 },
#                 {
#                     "name": "\u5927\u591a\u6570\u60c5\u51b5\u4e0b\u80fd\u56de\u7b54",
#                     "value": 0.19175276175142
#                 },
#                 {
#                     "name": "\u79ef\u6781\u53d1\u8a00",
#                     "value": 0.2146428731159712
#                 },
#                 {
#                     "name": "\u6ca1\u6709\u95ee\u7b54\u73af\u8282",
#                     "value": 0.08046983317679682
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{b|{b}: }{per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e0d\u56de\u7b54",
#                 "\u5076\u5c14\u53c2\u4e0e\u56de\u7b54",
#                 "\u5927\u591a\u6570\u60c5\u51b5\u4e0b\u80fd\u56de\u7b54",
#                 "\u79ef\u6781\u53d1\u8a00",
#                 "\u6ca1\u6709\u95ee\u7b54\u73af\u8282"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u7edf\u8ba1\u5b66\u751f\u7ebf\u4e0a\u4e92\u52a8\u9891\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1a3ca326d8d24e2399fa9cf78808cc8c.setOption(option_1a3ca326d8d24e2399fa9cf78808cc8c);
#         });
#     </script>

# %%
keys = ["网络卡顿","线上软件缺陷","与老师沟通不便", "作业不合理","课程质量欠佳","眼睛疲劳","软件太多容易混淆","环境干扰"]
res = [data[idx].value_counts()[1] for idx in range(49,57)]
res = numpy.array(res)
res = res / res.sum()

bar = create_bar(
    keys,
    list(res),
    title='线上学习问题统计',
    isRotated=True,
    isPercent=True
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c2722bb7cb02498e8d58805311f9fb94" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c2722bb7cb02498e8d58805311f9fb94 = echarts.init(
#                     document.getElementById('c2722bb7cb02498e8d58805311f9fb94'), 'white', {renderer: 'canvas'});
#                 var option_c2722bb7cb02498e8d58805311f9fb94 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 0.06168545262416344,
#                 0.31458111279351153,
#                 0.08637804604694355,
#                 0.1727217833241081,
#                 0.05766503661889361,
#                 0.04186813538698005,
#                 0.09645453173103755,
#                 0.1686459014743622
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data*100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7f51\u7edc\u5361\u987f",
#                 "\u7ebf\u4e0a\u8f6f\u4ef6\u7f3a\u9677",
#                 "\u4e0e\u8001\u5e08\u6c9f\u901a\u4e0d\u4fbf",
#                 "\u4f5c\u4e1a\u4e0d\u5408\u7406",
#                 "\u8bfe\u7a0b\u8d28\u91cf\u6b20\u4f73",
#                 "\u773c\u775b\u75b2\u52b3",
#                 "\u8f6f\u4ef6\u592a\u591a\u5bb9\u6613\u6df7\u6dc6",
#                 "\u73af\u5883\u5e72\u6270"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7ebf\u4e0a\u5b66\u4e60\u95ee\u9898\u7edf\u8ba1",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c2722bb7cb02498e8d58805311f9fb94.setOption(option_c2722bb7cb02498e8d58805311f9fb94);
#         });
#     </script>

# %%
# 培养能力
res = [data[idx].value_counts()[1] for idx in range(57,63)]
res = numpy.array(res)
res = res / res.sum()
res = [{"value": res.tolist(), "name": "培养能力"}]

MAX_VALUE = 0.35
radar_schema = [
    {"name": "自主学习能力", "max": MAX_VALUE},
    {"name": "自控能力", "max": MAX_VALUE},
    {"name": "数字化资源的利用能力", "max": MAX_VALUE},
    {"name": "表达沟通", "max": MAX_VALUE},
    {"name": "生活实践", "max": MAX_VALUE},
    {"name": "其他", "max": MAX_VALUE},
]

radar = create_radar(
    schema=radar_schema,
    data=res,
    minv=0,
    maxv=MAX_VALUE,
    title="统计学生线上学习培养能力"
)

radar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="df87d9460c994f9ea3707a9e8c586fd6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_df87d9460c994f9ea3707a9e8c586fd6 = echarts.init(
#                     document.getElementById('df87d9460c994f9ea3707a9e8c586fd6'), 'white', {renderer: 'canvas'});
#                 var option_df87d9460c994f9ea3707a9e8c586fd6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#4587E7"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "data": [
#                 {
#                     "value": [
#                         0.13061913463459035,
#                         0.3038342065541096,
#                         0.2289636267210326,
#                         0.13445233454325053,
#                         0.09794289353346858,
#                         0.1041878040135484
#                     ],
#                     "name": "\u57f9\u517b\u80fd\u529b"
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.1
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "radiusAxis": {
#         "min": 0,
#         "max": 0.35,
#         "scale": false,
#         "interval": 0.1,
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 1
#             }
#         }
#     },
#     "angleAxis": {
#         "clockwise": false,
#         "min": 0,
#         "max": 360,
#         "scale": false,
#         "splitNumber": 5,
#         "interval": 5,
#         "splitLine": {
#             "show": false,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "axisLine": {
#             "show": false,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         },
#         "axisTick": {
#             "show": false,
#             "alignWithLabel": false,
#             "inside": false
#         },
#         "axisLabel": {
#             "show": false,
#             "position": "top",
#             "margin": 8
#         }
#     },
#     "polar": {},
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u81ea\u4e3b\u5b66\u4e60\u80fd\u529b",
#                 "max": 0.35
#             },
#             {
#                 "name": "\u81ea\u63a7\u80fd\u529b",
#                 "max": 0.35
#             },
#             {
#                 "name": "\u6570\u5b57\u5316\u8d44\u6e90\u7684\u5229\u7528\u80fd\u529b",
#                 "max": 0.35
#             },
#             {
#                 "name": "\u8868\u8fbe\u6c9f\u901a",
#                 "max": 0.35
#             },
#             {
#                 "name": "\u751f\u6d3b\u5b9e\u8df5",
#                 "max": 0.35
#             },
#             {
#                 "name": "\u5176\u4ed6",
#                 "max": 0.35
#             }
#         ],
#         "shape": "circle",
#         "center": [
#             "50%",
#             "50%"
#         ],
#         "radius": "80%",
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": false,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": false,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "\u7edf\u8ba1\u5b66\u751f\u7ebf\u4e0a\u5b66\u4e60\u57f9\u517b\u80fd\u529b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_df87d9460c994f9ea3707a9e8c586fd6.setOption(option_df87d9460c994f9ea3707a9e8c586fd6);
#         });
#     </script>

# %%
keys = ["直播方式","录播方式","教师教学态度","教师教学水平","资源内容","线上学习平台","总体满意度"]

level1 = [
    {
        "value": data[idx].value_counts()[1] / NUMS,
        "percent": data[idx].value_counts()[1] / NUMS
    } 
    for idx in range(64,71)
]

level2 = [
    {
        "value":data[idx].value_counts()[2] / NUMS,
        "percent":data[idx].value_counts()[2] / NUMS
    }
    for idx in range(64,71)
]

level3 = [
    {
        "value":data[idx].value_counts()[3] / NUMS,
        "percent":data[idx].value_counts()[3] / NUMS
    } 
    for idx in range(64,71)
]

level4 = [
    {
        "value":data[idx].value_counts()[4] / NUMS,
        "percent":data[idx].value_counts()[4] / NUMS
    } 
    for idx in range(64,71)
]

bar = (
    Bar()
    .add_xaxis(keys)
    .add_yaxis("非常满意", level1, stack="stack1",category_gap="25%")
    .add_yaxis("满意",level2, stack="stack1", category_gap="25%")
    .add_yaxis("一般",level3, stack="stack1", category_gap="25%")
    .add_yaxis("不满意",level4, stack="stack1", category_gap="25%")
    .set_series_opts(
        label_opts=opts.LabelOpts(
            position="right",
            formatter=JsCode(
                "function(x){return Number(x.data.percent * 100).toFixed() + '%';}"
            ),
        )
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="线上学习满意度统计"),
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=30)),
    )
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="035a0aa696f94d538d7e728974f2a635" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_035a0aa696f94d538d7e728974f2a635 = echarts.init(
#                     document.getElementById('035a0aa696f94d538d7e728974f2a635'), 'white', {renderer: 'canvas'});
#                 var option_035a0aa696f94d538d7e728974f2a635 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u975e\u5e38\u6ee1\u610f",
#             "legendHoverLink": true,
#             "data": [
#                 {
#                     "value": 0.22293401665598975,
#                     "percent": 0.22293401665598975
#                 },
#                 {
#                     "value": 0.21992539032897776,
#                     "percent": 0.21992539032897776
#                 },
#                 {
#                     "value": 0.3445776136359096,
#                     "percent": 0.3445776136359096
#                 },
#                 {
#                     "value": 0.3186040719673007,
#                     "percent": 0.3186040719673007
#                 },
#                 {
#                     "value": 0.24170630000226412,
#                     "percent": 0.24170630000226412
#                 },
#                 {
#                     "value": 0.22426985207254266,
#                     "percent": 0.22426985207254266
#                 },
#                 {
#                     "value": 0.22874483412600005,
#                     "percent": 0.22874483412600005
#                 }
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "25%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data.percent * 100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6ee1\u610f",
#             "legendHoverLink": true,
#             "data": [
#                 {
#                     "value": 0.4214887039999148,
#                     "percent": 0.4214887039999148
#                 },
#                 {
#                     "value": 0.43990938161341747,
#                     "percent": 0.43990938161341747
#                 },
#                 {
#                     "value": 0.4724568850129388,
#                     "percent": 0.4724568850129388
#                 },
#                 {
#                     "value": 0.470772107543408,
#                     "percent": 0.470772107543408
#                 },
#                 {
#                     "value": 0.4701101831146674,
#                     "percent": 0.4701101831146674
#                 },
#                 {
#                     "value": 0.4410640868039971,
#                     "percent": 0.4410640868039971
#                 },
#                 {
#                     "value": 0.4519358958820842,
#                     "percent": 0.4519358958820842
#                 }
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "25%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data.percent * 100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u4e00\u822c",
#             "legendHoverLink": true,
#             "data": [
#                 {
#                     "value": 0.32264354237448406,
#                     "percent": 0.32264354237448406
#                 },
#                 {
#                     "value": 0.30979661472935016,
#                     "percent": 0.30979661472935016
#                 },
#                 {
#                     "value": 0.16784245932227995,
#                     "percent": 0.16784245932227995
#                 },
#                 {
#                     "value": 0.19282777578741706,
#                     "percent": 0.19282777578741706
#                 },
#                 {
#                     "value": 0.2675919402376801,
#                     "percent": 0.2675919402376801
#                 },
#                 {
#                     "value": 0.30282176918948217,
#                     "percent": 0.30282176918948217
#                 },
#                 {
#                     "value": 0.290606133655461,
#                     "percent": 0.290606133655461
#                 }
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "25%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data.percent * 100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u4e0d\u6ee1\u610f",
#             "legendHoverLink": true,
#             "data": [
#                 {
#                     "value": 0.03293373696961141,
#                     "percent": 0.03293373696961141
#                 },
#                 {
#                     "value": 0.030368613328254582,
#                     "percent": 0.030368613328254582
#                 },
#                 {
#                     "value": 0.015123042028871625,
#                     "percent": 0.015123042028871625
#                 },
#                 {
#                     "value": 0.0177960447018743,
#                     "percent": 0.0177960447018743
#                 },
#                 {
#                     "value": 0.020591576645388306,
#                     "percent": 0.020591576645388306
#                 },
#                 {
#                     "value": 0.03184429193397803,
#                     "percent": 0.03184429193397803
#                 },
#                 {
#                     "value": 0.02871313633645

# %%
keys = ["完全线下","线下为主，线上为辅","线上线下混合","完全线上"]
res = [data[90].value_counts()[idx]/NUMS for idx in range(1,5)]
res = [list(x) for x in zip(keys, res)]

pie = create_pie(res, '统计学生更喜欢哪种学习模式')
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b3769e5ea8434941b1aaef0e69edb5c8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b3769e5ea8434941b1aaef0e69edb5c8 = echarts.init(
#                     document.getElementById('b3769e5ea8434941b1aaef0e69edb5c8'), 'white', {renderer: 'canvas'});
#                 var option_b3769e5ea8434941b1aaef0e69edb5c8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b8c\u5168\u7ebf\u4e0b",
#                     "value": 0.4909454864611815
#                 },
#                 {
#                     "name": "\u7ebf\u4e0b\u4e3a\u4e3b\uff0c\u7ebf\u4e0a\u4e3a\u8f85",
#                     "value": 0.34487328209301304
#                 },
#                 {
#                     "name": "\u7ebf\u4e0a\u7ebf\u4e0b\u6df7\u5408",
#                     "value": 0.11874817704414117
#                 },
#                 {
#                     "name": "\u5b8c\u5168\u7ebf\u4e0a",
#                     "value": 0.045433054401664265
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{b|{b}: }{per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5b8c\u5168\u7ebf\u4e0b",
#                 "\u7ebf\u4e0b\u4e3a\u4e3b\uff0c\u7ebf\u4e0a\u4e3a\u8f85",
#                 "\u7ebf\u4e0a\u7ebf\u4e0b\u6df7\u5408",
#                 "\u5b8c\u5168\u7ebf\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u7edf\u8ba1\u5b66\u751f\u66f4\u559c\u6b22\u54ea\u79cd\u5b66\u4e60\u6a21\u5f0f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b3769e5ea8434941b1aaef0e69edb5c8.setOption(option_b3769e5ea8434941b1aaef0e69edb5c8);
#         });
#     </script>

# %%
res = [data[idx].value_counts()[1] for idx in range(71,78)]
res = numpy.array(res)
res = res / res.sum()
res = [{"value": res.tolist(), "name": "线上学习优势"}]

MAX_VALUE = 0.35
radar_schema = [
    {"name": "更多名师优质课", "max": MAX_VALUE},
    {"name": "学习效果更好", "max": MAX_VALUE},
    {"name": "减轻学习负担", "max": MAX_VALUE},
    {"name": "增强学习自主性", "max": MAX_VALUE},
    {"name": "随时随地学习", "max": MAX_VALUE},
    {"name": "其他", "max": MAX_VALUE},
]

radar = create_radar(
    schema=radar_schema,
    data=res,
    minv=0,
    maxv=MAX_VALUE,
    title="线上学习优势分析"
)

radar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="153351c0c4d84563822a5b8fba049a33" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_153351c0c4d84563822a5b8fba049a33 = echarts.init(
#                     document.getElementById('153351c0c4d84563822a5b8fba049a33'), 'white', {renderer: 'canvas'});
#                 var option_153351c0c4d84563822a5b8fba049a33 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#4587E7"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "data": [
#                 {
#                     "value": [
#                         0.17394370253218744,
#                         0.29184833960918977,
#                         0.06868469567933616,
#                         0.06586665711927032,
#                         0.15691353431640384,
#                         0.21300241227421576,
#                         0.029740658469396702
#                     ],
#                     "name": "\u7ebf\u4e0a\u5b66\u4e60\u4f18\u52bf"
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.1
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "radiusAxis": {
#         "min": 0,
#         "max": 0.35,
#         "scale": false,
#         "interval": 0.1,
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 1
#             }
#         }
#     },
#     "angleAxis": {
#         "clockwise": false,
#         "min": 0,
#         "max": 360,
#         "scale": false,
#         "splitNumber": 5,
#         "interval": 5,
#         "splitLine": {
#             "show": false,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "axisLine": {
#             "show": false,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         },
#         "axisTick": {
#             "show": false,
#             "alignWithLabel": false,
#             "inside": false
#         },
#         "axisLabel": {
#             "show": false,
#             "position": "top",
#             "margin": 8
#         }
#     },
#     "polar": {},
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u66f4\u591a\u540d\u5e08\u4f18\u8d28\u8bfe",
#                 "max": 0.35
#             },
#             {
#                 "name": "\u5b66\u4e60\u6548\u679c\u66f4\u597d",
#                 "max": 0.35
#             },
#             {
#                 "name": "\u51cf\u8f7b\u5b66\u4e60\u8d1f\u62c5",
#                 "max": 0.35
#             },
#             {
#                 "name": "\u589e\u5f3a\u5b66\u4e60\u81ea\u4e3b\u6027",
#                 "max": 0.35
#             },
#             {
#                 "name": "\u968f\u65f6\u968f\u5730\u5b66\u4e60",
#                 "max": 0.35
#             },
#             {
#                 "name": "\u5176\u4ed6",
#                 "max": 0.35
#             }
#         ],
#         "shape": "circle",
#         "center": [
#             "50%",
#             "50%"
#         ],
#         "radius": "80%",
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": false,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": false,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "\u7ebf\u4e0a\u5b66\u4e60\u4f18\u52bf\u5206\u6790",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_153351c0c4d84563822a5b8fba049a33.setOption(option_153351c0c4d84563822a5b8fba049a33);
#         });
#     </script>

# %%
keys = ["一年级", "二年级", "三年级", "四年级", "五年级", "六年级", "初一", "初二", "初三", "高一", "高二", "高三"]

counts = [0 for _ in range(12)] # 年级对应人数
values = [0 for _ in range(12)] # 年级学习时长总和

# 求平均
df = data.iloc[:,[1,22]]
df.columns = ['年级', '学习时长']
for grade in range(1,13):
    srl = df[df['年级'] == grade]['学习时长'] # 对应年级的学习时长列
    values[grade-1] = srl.to_numpy().sum() / srl.size

# 保留两位小数
values = numpy.round(values, 1)

line = create_line(
    keys=keys,
    values=values,
    title='学习时长和年龄关系分析',
    label='学习时长',
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3c879841c5e648fc85a7a45c8054926c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3c879841c5e648fc85a7a45c8054926c = echarts.init(
#                     document.getElementById('3c879841c5e648fc85a7a45c8054926c'), 'white', {renderer: 'canvas'});
#                 var option_3c879841c5e648fc85a7a45c8054926c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5b66\u4e60\u65f6\u957f",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u4e00\u5e74\u7ea7",
#                     4.2
#                 ],
#                 [
#                     "\u4e8c\u5e74\u7ea7",
#                     4.4
#                 ],
#                 [
#                     "\u4e09\u5e74\u7ea7",
#                     4.9
#                 ],
#                 [
#                     "\u56db\u5e74\u7ea7",
#                     5.0
#                 ],
#                 [
#                     "\u4e94\u5e74\u7ea7",
#                     5.1
#                 ],
#                 [
#                     "\u516d\u5e74\u7ea7",
#                     5.1
#                 ],
#                 [
#                     "\u521d\u4e00",
#                     6.5
#                 ],
#                 [
#                     "\u521d\u4e8c",
#                     6.6
#                 ],
#                 [
#                     "\u521d\u4e09",
#                     6.9
#                 ],
#                 [
#                     "\u9ad8\u4e00",
#                     6.7
#                 ],
#                 [
#                     "\u9ad8\u4e8c",
#                     6.7
#                 ],
#                 [
#                     "\u9ad8\u4e09",
#                     7.1
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5b66\u4e60\u65f6\u957f"
#             ],
#             "selected": {
#                 "\u5b66\u4e60\u65f6\u957f": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": true,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e00\u5e74\u7ea7",
#                 "\u4e8c\u5e74\u7ea7",
#                 "\u4e09\u5e74\u7ea7",
#                 "\u56db\u5e74\u7ea7",
#                 "\u4e94\u5e74\u7ea7",
#                 "\u516d\u5e74\u7ea7",
#                 "\u521d\u4e00",
#                 "\u521d\u4e8c",
#                 "\u521d\u4e09",
#                 "\u9ad8\u4e00",
#                 "\u9ad8\u4e8c",
#                 "\u9ad8\u4e09"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5b66\u4e60\u65f6\u957f\u548c\u5e74\u9f84\u5173\u7cfb\u5206\u6790",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3c879841c5e648fc85a7a45c8054926c.setOption(option_3c879841c5e648fc85a7a45c8054926c);
#         });
#     </script>
