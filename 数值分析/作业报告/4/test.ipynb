# %%
from json import load
with open('page_rank.json', 'r') as f:
    data = load(f)

for i, token in enumerate(data):
    msg = 'Rank %d Value = %f URL:%s' % (i+1, token[1], token[0])
    print(msg)
# Out:
# k 259 Value = 0.001140
# URL:https://iesr.jnu.edu.cn/zlxz/list.htm
# Rank 260 Value = 0.001130
# URL:https://zhlib.jnu.edu.cn/promotional_film/index.html
# Rank 261 Value = 0.001130
# URL:https://zhdzb.jnu.edu.cn
# Rank 262 Value = 0.001130
# URL:https://zhjw.jnu.edu.cn
# Rank 263 Value = 0.001130
# URL:https://zhtgw.jnu.edu.cn
# Rank 264 Value = 0.001130
# URL:https://zhcw.jnu.edu.cn
# Rank 265 Value = 0.001130
# URL:https://zhzhb.jnu.edu.cn
# Rank 266 Value = 0.001130
# URL:https://zhpe.jnu.edu.cn
# Rank 267 Value = 0.001130
# URL:https://zhmodern.jnu.edu.cn
# Rank 268 Value = 0.001127
# URL:https://www.jnu.edu.cn/2591/list.htm
# Rank 269 Value = 0.001124
# URL:https://hrdam.jnu.edu.cn/328/list.htm
# Rank 270 Value = 0.001123
# URL:https://news.jnu.edu.cn/jnyw/yw/2020/12/14/17083747729.html
# Rank 271 Value = 0.001115
# URL:https://iesr.jnu.edu.cn/hdyg/list.htm
# Rank 272 Value = 0.001112
# URL:https://hrdam.jnu.edu.cn/bshgl_22653/list.htm
# Rank 273 Value = 0.001109
# ...
